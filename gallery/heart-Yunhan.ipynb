# %% [markdown]
# ### Heart by Yunhan

# %%
# !pip install ColabTurtlePlus
from ColabTurtlePlus.Turtle import *
from ColabTurtlePlus.Turtle import Turtle

speed(13)
t=Turtle()
initializeTurtle()

t.fillcolor("black")
t.begin_fill()
t.fd(20)
t.left(90)
t.fd(20)
t.right(90)
t.fd(20)
t.left(90)
t.fd(20)
t.right(90)
t.fd(40)
t.right(90)

t.fd(20)
t.left(90)
t.fd(20)
t.right(90)
t.fd(20)
t.left(90)
t.fd(20)
t.right(90)
t.fd(60)
t.right(90)

for i in range(5):
  t.fd(20)
  t.left(90)
  t.fd(20)
  t.right(90)
t.fd(20)
t.right(90)
for i in range(5):
  t.fd(20)
  t.left(90)
  t.fd(20)
  t.right(90)  
t.fd(60)
t.right(90)
t.fd(20)
t.left(90)
t.fd(20)
t.right(90)
t.fd(20)
t.left(90)
t.fd(20)
t.right(90)
t.fd(40)
t.right(90)
t.fd(20)
t.left(90)
t.fd(20)
t.right(90)
t.fd(20)
t.end_fill()

#内部红色爱心
t.fillcolor("red")
t.begin_fill()
t.fd(20)
t.left(90)


t.fd(20)
t.left(90)
t.fd(20)
t.right(90)
t.fd(20)
t.left(90)
t.fd(20)
t.right(90)
t.fd(40)
t.right(90)

t.fd(20)
t.left(90)
t.fd(20)
t.right(90)
t.fd(60)
t.right(90)

for i in range(4):
  t.fd(20)
  t.left(90)
  t.fd(20)
  t.right(90)

t.fd(20)
t.right(90)

for i in range(4):
  t.fd(20)
  t.left(90)
  t.fd(20)
  t.right(90)

t.fd(60)
t.right(90)
t.fd(20)
t.left(90)
t.fd(20)
t.right(90)
t.fd(40)
t.right(90)
t.fd(20)
t.left(90)
t.fd(20)
t.right(90)
t.fd(20)
t.end_fill()

t.penup()
t.left(90)
t.fd(40)
t.pendown()
t.fillcolor("white")
t.begin_fill()
t.fd(20)
t.right(90)
t.fd(20)
t.left(90)
t.fd(20)
t.left(90)
t.fd(40)
t.left(90)
t.fd(40)
t.left(90)
t.end_fill()
t.ht()
hideturtle()
# Out:
# Requirement already satisfied: ColabTurtlePlus in /Users/yongxinlyu/opt/anaconda3/envs/CEIC6789/lib/python3.13/site-packages (2.0.1)
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path fill-rule="evenodd" fill-opacity="1" d="M 400.0 300.0  L 420.0 300.0  L 420.0 280.0  L 440.0 280.0  L 440.0 260.0  L 480.0 260.0  L 480.0 280.0  L 500.0 280.0  L 500.0 300.0  L 520.0 300.0  L 520.0 360.0  L 500.0 360.0  L 500.0 380.0  L 480.0 380.0  L 480.0 400.0  L 460.0 400.0  L 460.0 420.0  L 440.0 420.0  L 440.0 440.0  L 420.0 440.0  L 420.0 460.0  L 400.0 460.0  L 400.0 440.0  L 380.0 440.0  L 380.0 420.0  L 360.0 420.0  L 360.0 400.0  L 340.0 400.0  L 340.0 380.0  L 320.0 380.0  L 320.0 360.0  L 300.0 360.0  L 300.0 300.0  L 320.0 300.0  L 320.0 280.0  L 340.0 280.0  L 340.0 260.0  L 380.0 260.0  L 380.0 280.0  L 400.0 280.0  L 400.0 300.0 " stroke-linecap="round" style="stroke:black;stroke-width:1" fill="black" /><path fill-rule="evenodd" fill-opacity="1" d="M 400.0 300.0  L 400.0 320.0  L 420.0 320.0  L 420.0 300.0  L 440.0 300.0  L 440.0 280.0  L 480.0 280.0  L 480.0 300.0  L 500.0 300.0  L 500.0 360.0  L 480.0 360.0  L 480.0 380.0  L 460.0 380.0  L 460.0 400.0  L 440.0 400.0  L 440.0 420.0  L 420.0 420.0  L 420.0 440.0  L 400.0 440.0  L 400.0 420.0  L 380.0 420.0  L 380.0 400.0  L 360.0 400.0  L 360.0 380.0  L 340.0 380.0  L 340.0 360.0  L 320.0 360.0  L 320.0 300.0  L 340.0 300.0  L 340.0 280.0  L 380.0 280.0  L 380.0 300.0  L 400.0 300.0  L 400.0 320.0 " stroke-linecap="round" style="stroke:black;stroke-width:1" fill="red" /><path fill-rule="evenodd" fill-opacity="1" d="M 440.0 320.0  L 460.0 320.0  L 460.0 340.0  L 480.0 340.0  L 480.0 300.0  L 440.0 300.0 " stroke-linecap="round" style="stroke:black;stroke-width:1" fill="white" />
#
#
#         <g id="classic" visibility="hidden" transform="rotate(-90,400.0,300.0) translate(400.0, 300.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:black;fill:black;stroke-width:1" />
# </g><g id="classic" visibility="hidden" transform="rotate(0,440.0,300.0) translate(440.0, 300.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:black;fill:white;stroke-width:1" />
# </g>
#       </svg>
